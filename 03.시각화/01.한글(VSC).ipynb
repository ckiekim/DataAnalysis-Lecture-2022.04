# %% [markdown]
# # Matplotlib - 한글

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([0,1,2,3],[0,1,4,9])   # X, Y
plt.title('Line plot')          # 제목
plt.grid()                      # 격자선
plt.show()          # 합쳐서 화면에 보이게 함

# %%
plt.plot([0,1,2,3],[0,1,4,9])   # X, Y
plt.title('라인 플롯')          # 제목
plt.grid()                      # 격자선
plt.show()
# Out:
# C:\Users\ezen\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 46972 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ezen\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ezen\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54540 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ezen\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 47215 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ezen\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 46972 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\ezen\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\ezen\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54540 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\ezen\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 47215 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# - 한글 설정

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %%
mpl.rcParams['axes.unicode_minus'] = False

# %%
mpl.rcParams['font.family'] = 'Malgun Gothic'

# %%
plt.plot([0,1,2,3],[0,1,4,9])   # X, Y
plt.title('라인 플롯')          # 제목
plt.grid()                      # 격자선
plt.show()
